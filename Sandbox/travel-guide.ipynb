# %% [markdown]
# ## read input

# %%
import json

def read_json_file(file_path):
    """Reads and parses a JSON file.

    Args:
        file_path (str): The path to the JSON file.

    Returns:
        dict or list or None: The parsed JSON data, or None if an error occurs.
    """
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
            return data
    except FileNotFoundError:
        print(f"Error: JSON file not found at {file_path}")
        return None
    except json.JSONDecodeError:
        print(f"Error: Failed to parse JSON in file {file_path}")
        return None

def read_text_file(file_path):
    """Reads a plain text file.

    Args:
        file_path (str): The path to the text file.

    Returns:
        str or None: The content of the text file as a string, or None if an error occurs.
    """
    try:
        with open(file_path, 'r') as file:
            content = file.read()
            return content
    except FileNotFoundError:
        print(f"Error: Text file not found at {file_path}")
        return None
    except Exception as e:
        print(f"Error reading text file {file_path}: {e}")
        return None

# Read the JSON file
individual_file_path = 'prompt/prompt-itinerary-individual-01.json'
individual_json = read_json_file(details_file_path)

# Read the text file
instructions_file_path = 'prompt/prompt-itinerary-general-instruction-01.txt' 
instructions_text = read_text_file(instructions_file_path)

# Print the data from both files
if details_json:
    print("JSON Data:")
    print(individual_json)

if instructions_text is not None:
    print("\nText File Content:")
    print(instructions_text)
# Out:
# JSON Data:
# {'destination': 'Waldviertel, starting from Wilhelmsburg, Lower Austria', 'duration': '3 days', 'preferences': 'History, Gothic and Romanesque architecture, natural monuments, scenic routes, picnics in nice surroundings', 'need': 'Flexibility for weather conditions, off-road car for overnight stay with family and big dog', 'context': 'Family trip with 2-year-old kid and big dog, avoid long trips. Take into account, that we already have been there, so we already know the usual tourist points.', 'tone': 'Mark Twain', 'style': 'Engaging and clear writing style'}
#
# Text File Content:
# Propose an travel itinerary useful for a travel guide, generate a map including the routes and the proposed points of interests. Additionally, list all proposed points of interests as json for further processing in Python to generate location map, display images with free licence, and to prompt for a description.
#
# destination: Waldviertel, starting from Wilhelmsburg, Lower Austria
# duration: 3 days
# preferences: History, Gothic and Romanesque architecture, natural monuments, scenic routes, picnics in nice surroundings.
# need: Flexibility for weather conditions, off-road car for overnight stay with family and big dog
# context: Family trip with 2-year-old kid and big dog, avoid long trips. Take into account, that we already have been there, so we already know the usual tourist points.
# tone: Mark Twain
# style: Engaging and clear writing style

# %%
# Create a prompt
formatted_lines = []
prompt_itinerary = ""

# Add general instructions
formatted_lines.append(instructions_text)

# Add details
if individual_json: # Proceed only if data_dict is not empty
    for key, value in individual_json.items():
        # Use an f-string to format each line
        formatted_lines.append(f"{key}: {value}")

    # Join the lines together with newline characters
    prompt_itinerary = "\n".join(formatted_lines)

    # --- Step 4: Print or use the output text ---
    print(prompt_itinerary)

else:
    print("Could not process details.")
# Out:
# Propose an travel itinerary useful for a travel guide, generate a map including the routes and the proposed points of interests. Additionally, list all proposed points of interests as json for further processing in Python to generate location map, display images with free licence, and to prompt for a description.
#
# destination: Waldviertel, starting from Wilhelmsburg, Lower Austria
# duration: 3 days
# preferences: History, Gothic and Romanesque architecture, natural monuments, scenic routes, picnics in nice surroundings.
# need: Flexibility for weather conditions, off-road car for overnight stay with family and big dog
# context: Family trip with 2-year-old kid and big dog, avoid long trips. Take into account, that we already have been there, so we already know the usual tourist points.
# tone: Mark Twain
# style: Engaging and clear writing style
# destination: Waldviertel, starting from Wilhelmsburg, Lower Austria
# duration: 3 days
# preferences: History, Gothic and Romanesque architecture, natural monuments, scenic routes, picnics in nice surroundings
# need: Flexibility for weather conditions, off-road car for overnight stay with family and big dog
# context: Family trip with 2-year-old kid and big dog, avoid long trips. Take into account, that we already have been there, so we already know the usual tourist points.
# tone: Mark Twain
# style: Engaging and clear writing style

# %% [markdown]
# ## query LLM - Google - Gemini

# %%
# Set API key
my_api_key = 'XXX'

# %%
from google import genai

try:
    client = genai.Client(api_key=my_api_key)
    
    # Choose a model (e.g., gemini-1.5-flash)
    # Check the documentation for available models: https://ai.google.dev/gemini-api/docs/models
    response = client.models.generate_content(
        model="gemini-2.0-flash",
        contents=prompt_itinerary,
    )
    
    print(response.text)
except ValueError as e:
    print(f"Error: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Alright folks, gather 'round! Planning a Waldviertel adventure, are we? A region so rugged and charming, it could charm the bark off a dog (and yours is a big 'un, I hear!).  Since you're already acquainted with the usual suspects, we'll ditch the tourist traps and venture off the beaten path.  Now, considering the little sprout and the four-legged behemoth, and knowing Waldviertel's temperament (changeable as a politician's promises), flexibility is key. This itinerary is more of a suggestion box than a rigid schedule. Pack your sense of humor, your picnic basket, and your off-road chariot!
#
# **The Waldviertel Wanderer's 3-Day Itinerary (Mark Twain Approved)**
#
# **Day 1: Whispers of Stone and Ancient Woods (Wilhelmsburg to Ottenschlag)**
#
# *   **Morning (9:00 AM):**  Hit the road from Wilhelmsburg, pointing your iron steed northward.  Avoid the highway like the plague; we're hunting for scenic routes!
# *   **Morning (10:30 AM):**  **Ruprechtshofen - Hidden Romanesque Church** (Point of Interest 1):  We're making a pit stop in Ruprechtshofen for a glimpse into the past. You've seen the flashy cathedrals, but have you laid eyes on this unassuming Romanesque gem, St. Rupertus? This one is a hidden pearl, it is so unvisible, it is a miracle you haven't stumbled upon it yet.
# *   **Noon (12:00 PM):** **Picnic by the Kamp River (near Schönbach):** Find a picturesque spot along the Kamp River (around Schönbach). Pack a hearty lunch (sausage, cheese, maybe some of that Austrian bread that could double as a weapon if wielded correctly). Let the little one throw pebbles, the dog sniff suspiciously, and you contemplate the river's journey through time.
# *   **Afternoon (2:00 PM):  Schloss Rosenau:** (Point of Interest 2) - Forget Schönbrunn; we're going local!  Schloss Rosenau might not be dripping in gold leaf, but it offers a peaceful escape. Stroll through the gardens, imagine yourself as a local lord (or lady), and enjoy the fresh air. The grounds are perfect for a toddler to explore (within reason, of course).
# *   **Late Afternoon (4:00 PM):  Steinrelief in Großglobnitz (near Grafenschlag)** (Point of Interest 3):  This is where things get quirky. This is a bizarrely impressive stone sculpture. A must-see, not easily found, but worth a trip.
# *   **Evening (6:00 PM): Ottenschlag - Check-in and Dinner:** Aim for a family-friendly *Gasthof* (inn) in Ottenschlag or nearabouts.  Many offer traditional Waldviertel cuisine – hearty, stick-to-your-ribs stuff.  The dog will likely appreciate dropped scraps (discreetly, of course). Consider camping around the area for off-road freedom, but be prepared to be off-grid.
#
# **Day 2: Stones, Forests, and Dwarves (Ottenschlag to Gmünd)**
#
# *   **Morning (9:00 AM):  Stift Zwettl (near Zwettl):** (Point of Interest 4): You've seen your share of abbeys, but Stift Zwettl is special. It's not just the architecture, but the sense of peace that settles over you as you walk through its courtyards. The Baroque interior is a marvel, but the Romanesque cloister is the real showstopper.
# *   **Noon (11:00 AM):  Blockheide Eibenstein Nature Park (near Gmünd):** (Point of Interest 5): Giants Kisses, and a little bit of everything that makes the Waldviertel special: bizarrely shaped granite boulders.
# *   **Afternoon (3:00 PM):  UnterWasserReich Schrems (near Schrems):** (Point of Interest 6):  While the name might sound like something out of Jules Verne, this is a fascinating nature experience. Explore the underwater world of the moors, learn about the local flora and fauna, and let the little one marvel at the fish. It's educational without being boring.
# *   **Evening (6:00 PM): Gmünd - Find your digs and sample the local fare:** Gmünd has a nice old town to walk around and enjoy. Search again for some local inn to replenish after a day of discoveries. Camping is again welcome, and the area is well worth it.
#
# **Day 3: Bohemian Borderlands and a Taste of the Past (Gmünd to Wilhelmsburg)**
#
# *   **Morning (9:00 AM):  Lookout tower "Himmelsstiege" (near Bad Großpertholz):** (Point of Interest 7): This tower is a great spot to take advantage of a beautiful view. If it rains, the visit is probably not worth it.
# *   **Morning (11:00 AM):  Burg Heidenreichstein (near Heidenreichstein):** (Point of Interest 8):  A medieval fortress that looks like it leaped straight out of a fairy tale. Explore the imposing walls, wander through the castle grounds, and imagine yourself as a knight defending the realm. The little one will love running around (carefully, of course!), and the dog will appreciate the new smells.
# *   **Noon (1:00 PM):  Picnic near a Pond (Waldviertel is full of them!):**  Find a tranquil pond for a final Waldviertel picnic. Let the dog cool off his paws, throw some bread crumbs to the ducks, and soak in the peaceful atmosphere.
# *   **Afternoon (3:00 PM):  Freilichtmuseum Weitra (near Weitra):** (Point of Interest 9): This open-air museum offers a fascinating glimpse into the rural life of the Waldviertel in centuries past. Explore traditional farmhouses, workshops, and gardens, and learn about the customs and traditions of the region. It's a great way to bring history to life for the little one.
# *   **Evening (5:00 PM): Head back to Wilhelmsburg:** Time to point the trusty steed homeward. Reflect on your Waldviertel adventure and start planning your next escapade!
#
# **Important Considerations:**
#
# *   **Weather:** Be prepared for anything. Pack layers, rain gear, and sunscreen.
# *   **Dog-Friendliness:**  While Austria is generally dog-friendly, always check in advance if your four-legged friend is welcome at restaurants and attractions. Keep him on a leash in nature reserves.
# *   **Toddler-Friendliness:** Pack snacks, drinks, and entertainment for the little one. Be prepared for frequent stops.
# *   **Off-Roading:** Not all roads in the Waldviertel are paved. An off-road vehicle is highly recommended, especially if you plan on camping.
# *   **Flexibility:** This is just a suggestion. Feel free to adjust the itinerary based on your family's needs and interests.
# *   **Language:** Brush up on your German (or at least learn a few basic phrases).
# *   **Reservations:** Especially during peak season, it's wise to book accommodations in advance.
#
# **Map (Conceptual - Needs Real Map Integration):**
#
# *(Imagine a map of Lower Austria, zoomed in on the Waldviertel.  Key locations are marked, and routes are indicated with dotted lines. The map would highlight:*
#
# *   *Wilhelmsburg (Starting Point)*
# *   *Ruprechtshofen*
# *   *Schönbach (Picnic Area)*
# *   *Schloss Rosenau*
# *   *Grafenschlag*
# *   *Ottenschlag*
# *   *Zwettl*
# *   *Gmünd*
# *   *Schrems*
# *   *Bad Großpertholz*
# *   *Heidenreichstein*
# *   *Weitra*
#
# *   *Arrows indicate the general direction of travel each day.*
#
# **JSON for Points of Interest:**
#
# ```json
# [
#   {
#     "id": 1,
#     "name": "St. Rupertus, Ruprechtshofen",
#     "latitude": 48.169077,
#     "longitude": 15.381938,
#     "description": "Hidden Romanesque church, unassuming but historically significant.",
#     "image_search_terms": "Romanische Kirche Ruprechtshofen",
#     "free_license_image_url": null,
#     "needs_description": true
#   },
#   {
#     "id": 2,
#     "name": "Schloss Rosenau",
#     "latitude": 48.600300,
#     "longitude": 15.088400,
#     "description": "Peaceful castle with gardens, ideal for families and a quiet stroll.",
#     "image_search_terms": "Schloss Rosenau Waldviertel",
#     "free_license_image_url": null,
#     "needs_description": true
#   },
#   {
#     "id": 3,
#     "name": "Steinrelief in Großglobnitz",
#     "latitude": 48.620433,
#     "longitude": 15.180097,
#     "description": "Bizarre stone sculpture, a unique and offbeat attraction.",
#     "image_search_terms": "Steinrelief Grossglobnitz",
#     "free_license_image_url": null,
#     "needs_description": true
#   },
#   {
#     "id": 4,
#     "name": "Stift Zwettl",
#     "latitude": 48.604800,
#     "longitude": 15.151500,
#     "description": "Baroque abbey with a beautiful Romanesque cloister, a haven of peace and history.",
#     "image_search_terms": "Stift Zwettl",
#     "free_license_image_url": null,
#     "needs_description": true
#   },
#   {
#     "id": 5,
#     "name": "Blockheide Eibenstein Nature Park",
#     "latitude": 48.787800,
#     "longitude": 14.997500,
#     "description": "Nature park with granite boulders and a unique landscape.",
#     "image_search_terms": "Blockheide Eibenstein",
#     "free_license_image_url": null,
#     "needs_description": true
#   },
#   {
#     "id": 6,
#     "name": "UnterWasserReich Schrems",
#     "latitude": 48.773900,
#     "longitude": 15.073200,
#     "description": "Nature park exploring the underwater world of moors, educational and engaging.",
#     "image_search_terms": "UnterWasserReich Schrems",
#     "free_license_image_url": null,
#     "needs_description": true
#   },
#   {
#     "id": 7,
#     "name": "Lookout tower \"Himmelsstiege\"",
#     "latitude": 48.618357,
#     "longitude": 14.783385,
#     "description": "Lookout tower with wide view",
#     "image_search_terms": "Aussichtsturm Himmelsstiege Bad Großpertholz",
#     "free_license_image_url": null,
#     "needs_description": true
#   },
#   {
#     "id": 8,
#     "name": "Burg Heidenreichstein",
#     "latitude": 48.824600,
#     "longitude": 15.211200,
#     "description": "Medieval fortress with imposing walls and grounds, great for exploring and imagining a knight's life.",
#     "image_search_terms": "Burg Heidenreichstein",
#     "free_license_image_url": null,
#     "needs_description": true
#   },
#   {
#     "id": 9,
#     "name": "Freilichtmuseum Weitra",
#     "latitude": 48.707300,
#     "longitude": 14.884300,
#     "description": "Open-air museum showcasing rural life in the Waldviertel, a step back in time.",
#     "image_search_terms": "Freilichtmuseum Weitra",
#     "free_license_image_url": null,
#     "needs_description": true
#   }
# ]
# ```
#
# **Further Python Processing (Conceptual):**
#
# Using the JSON data, a Python script (using libraries like `folium`, `requests`, `PIL`, and potentially image search APIs like Flickr's or Wikimedia Commons') could:
#
# 1.  **Generate a Leaflet Map:**  Use `folium` to create an interactive map centered on the Waldviertel. Add markers for each point of interest, using the latitude and longitude.
# 2.  **Fetch Images:** Use the `image_search_terms` to query image repositories (e.g., Wikimedia Commons) for free-license images of each location.  Display these images in pop-up windows on the map when a marker is clicked.
# 3.  **Prompt for Descriptions:**  For entries where `needs_description` is true, prompt the user (you!) to provide a more detailed description.  This description could then be stored back in the JSON file.
# 4.  **Display Descriptions:** Display the descriptions for each location in the pop-up windows on the map, alongside the fetched images.
#
# There you have it!  A Waldviertel adventure worthy of a story or two, and flexible enough to handle whatever Mother Nature throws your way. Now, get out there and explore!  And don't forget to write it all down - for posterity, you understand.  Happy trails!
