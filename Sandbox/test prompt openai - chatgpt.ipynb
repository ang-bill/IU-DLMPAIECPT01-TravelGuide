# %% [markdown]
# ## read input

# %%
import json

def read_json_file(file_path):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
            return data
    except FileNotFoundError:
        print(f"File {file_path} not found.")
        return None
    except json.JSONDecodeError:
        print(f"Failed to parse JSON in file {file_path}.")
        return None


# Read the JSON file
file_path = '../prompt/prompt-itinerary-01.json'
data = read_json_file(file_path)

# Print the data
if data:
    print(data)
# Out:
# File ../prompt/prompt-itinerary-01.json not found.

# %% [markdown]
# ## query LLM - OpenAI - ChatGPT

# %%
# 1. Set your API key
#openai.api_key = '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'

# %%
from openai import OpenAI

#client = OpenAI()
client = openai.OpenAI(api_key="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")  # Or: client = openai.OpenAI(api_key="sk-...")

response = client.responses.create(
  model="gpt-4.1",
  input="Tell me a three sentence bedtime story about a unicorn."
)

print(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 from openai import OpenAI
#       3 #client = OpenAI()
# ----> 4 client = openai.OpenAI(api_key="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")  # Or: client = openai.OpenAI(api_key="sk-...")
#       6 response = client.responses.create(
#       7   model="gpt-4.1",
#       8   input="Tell me a three sentence bedtime story about a unicorn."
#       9 )
#      11 print(response)
#
# NameError: name 'openai' is not defined

# %%
import openai

# API key
openai_api_key = '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'

# Initialize the OpenAI client — make sure your API key is set as an environment variable or directly here
# client = openai.OpenAI(api_key=openai_api_key)  # Or: client = openai.OpenAI(api_key="sk-...")
client = openai.OpenAI(api_key="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")  # Or: client = openai.OpenAI(api_key="sk-...")

# Send the chat prompt
response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful travel guide assistant."},
        {"role": "user", "content": "Describe Pfarrkirche St. Martin im Waldviertel in an engaging style."}
    ],
    temperature=0.7
)

# Extract and print the reply
reply = response.choices[0].message.content
print(reply)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[4], line 11
#       8 client = openai.OpenAI(api_key="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")  # Or: client = openai.OpenAI(api_key="sk-...")
#      10 # Send the chat prompt
# ---> 11 response = client.chat.completions.create(
#      12     model="gpt-3.5-turbo",
#      13     messages=[
#      14         {"role": "system", "content": "You are a helpful travel guide assistant."},
#      15         {"role": "user", "content": "Describe Pfarrkirche St. Martin im Waldviertel in an engaging style."}
#      16     ],
#      17     temperature=0.7
#      18 )
#      20 # Extract and print the reply
#      21 reply = response.choices[0].message.content
#
# ...
